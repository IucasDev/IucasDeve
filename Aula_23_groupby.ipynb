# %% [markdown]
# <a href="https://colab.research.google.com/github/IucasDev/IucasDeve/blob/main/Aula_23_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/cadastro_clientes.csv")
df
# Out:
#     ID_Cliente                      Nome  Idade       Sexo  \
# 0            1               Esther Lima     61  Masculino
# 1            2              Bryan Araújo     27   Feminino
# 2            3               Laís Mendes     28  Masculino
# 3            4      Srta. Ana Clara Lima     34   Feminino
# 4            5            Esther Pereira     26  Masculino
# 5            6      Maria Clara Silveira     58   Feminino
# 6            7                Lara Moura     41   Feminino
# 7            8  Sr. João Felipe Monteiro     52  Masculino
# 8            9           Eduardo Freitas     53  Masculino
# 9           10                Levi Pires     39   Feminino
# 10          11             Mariane Jesus     49   Feminino
# 11          12           Ana Julia Viana     62  Masculino
# 12          13           Bernardo Duarte     68  Masculino
# 13          14       Vitor Hugo da Costa     48  Masculino
# 14          15            Leandro Castro     28  Masculino
# ...

# %%
 # Contagem de quando registros (Linhas existem por grupo de Estado) usando o groupby
df.groupby("Estado")["ID_Cliente"].count()
# Out:
# Estado
# AP    1
# CE    1
# ES    2
# MG    2
# PE    1
# PI    1
# PR    3
# RJ    1
# RN    2
# RO    1
# RR    2
# SE    2
# TO    1
# Name: ID_Cliente, dtype: int64

# %%
#faz a contagem em ordem (sem o groupby)
df["Estado"].value_counts()
# Out:
# Estado
# PR    3
# ES    2
# RN    2
# SE    2
# MG    2
# RR    2
# PI    1
# PE    1
# CE    1
# RJ    1
# TO    1
# AP    1
# RO    1
# Name: count, dtype: int64

# %%
# valores percentuais

df["Estado"].value_counts(normalize= True)
# Out:
# Estado
# PR    0.15
# ES    0.10
# RN    0.10
# SE    0.10
# MG    0.10
# RR    0.10
# PI    0.05
# PE    0.05
# CE    0.05
# RJ    0.05
# TO    0.05
# AP    0.05
# RO    0.05
# Name: proportion, dtype: float64

# %%
# valores percentuais multiplicado por 100

df["Estado"].value_counts(normalize= True) *100
# Out:
# Estado
# PR    15.0
# ES    10.0
# RN    10.0
# SE    10.0
# MG    10.0
# RR    10.0
# PI     5.0
# PE     5.0
# CE     5.0
# RJ     5.0
# TO     5.0
# AP     5.0
# RO     5.0
# Name: proportion, dtype: float64

# %% [markdown]
# RESUMO DA FUNÇOES

# %%
#resumo de funçoes
#MENOR IDADE
df ["Idade"].min()
# Out:
# 26

# %%
#MAIOR SALARIO
df["Gasto_Total"].max()
# Out:
# 9976.92

# %%
#Descriçoes
df["Gasto_Total"].describe()
# Out:
# count      20.000000
# mean     6453.034500
# std      1969.422692
# min      2443.250000
# 25%      5201.757500
# 50%      6813.730000
# 75%      7378.345000
# max      9976.920000
# Name: Gasto_Total, dtype: float64
